# %% [markdown]
# <a href="https://colab.research.google.com/github/muhardan/tugas-streamlit-diabetes/blob/main/app.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install streamlit if not already installed
# !pip install streamlit

import streamlit as st
import pandas as pd
import pickle
import numpy as np

# %%
# Konfigurasi Halaman
st.set_page_config(page_title="Prediksi Diabetes", layout="wide")
# Out:
# 2026-05-05 03:38:55.816 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# --- HEADER ---
st.title('Aplikasi Prediksi Penyakit Diabetes')
st.write('Dibuat oleh: Rama (Tugas Praktik Streamlit)')
st.markdown('---')
# Out:
# 2026-05-05 03:38:55.837 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-05 03:38:55.843 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-05 03:38:55.848 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-05 03:38:55.854 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-05 03:38:55.856 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-05 03:38:55.858 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-05 03:38:55.861 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
# --- LOAD MODEL ---
# Pastikan file 'diabetes_model.sav' sudah ada di folder yang sama di GitHub
@st.cache_resource
def load_model():
    try:
        model = pickle.load(open('diabetes_model.sav', 'rb'))
        return model
    except FileNotFoundError:
        st.error("Model 'diabetes_model.sav' tidak ditemukan. Pastikan sudah diunggah ke GitHub.")
        return None

model = load_model()

# %%
# --- INPUT DATA ---
st.sidebar.header('Input Data Pasien')

def user_input_features():
    pregnancies = st.sidebar.number_input('Jumlah Kehamilan', min_value=0, max_value=20, value=1)
    glucose = st.sidebar.number_input('Kadar Glukosa', min_value=0, max_value=200, value=100)
    blood_pressure = st.sidebar.number_input('Tekanan Darah', min_value=0, max_value=150, value=70)
    skin_thickness = st.sidebar.number_input('Ketebalan Kulit', min_value=0, max_value=100, value=20)
    insulin = st.sidebar.number_input('Kadar Insulin', min_value=0, max_value=900, value=79)
    bmi = st.sidebar.number_input('Indeks Massa Tubuh (BMI)', min_value=0.0, max_value=70.0, value=25.0)
    diabetes_pedigree = st.sidebar.number_input('Diabetes Pedigree Function', min_value=0.0, max_value=3.0, value=0.5)
    age = st.sidebar.number_input('Usia', min_value=1, max_value=120, value=30)

    data = {
        'Pregnancies': pregnancies,
        'Glucose': glucose,
        'BloodPressure': blood_pressure,
        'SkinThickness': skin_thickness,
        'Insulin': insulin,
        'BMI': bmi,
        'DiabetesPedigreeFunction': diabetes_pedigree,
        'Age': age
    }
    features = pd.DataFrame(data, index=[0])
    return features

input_df = user_input_features()
# Out:
# 2026-05-05 03:38:55.909 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-05 03:38:55.910 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-05 03:38:55.911 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-05 03:38:55.913 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-05 03:38:55.915 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-05 03:38:55.917 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-05 03:38:55.917 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
# Menampilkan inputan
st.subheader('Data Pasien yang Diinput:')
st.write(input_df)

# --- PREDIKSI ---
if st.button('Cek Hasil Prediksi'):
    if model is not None:
        prediction = model.predict(input_df)

        st.markdown('---')
        st.subheader('Hasil Analisis:')
        if prediction[0] == 1:
            st.error('⚠️ Berdasarkan data tersebut, pasien terdeteksi terkena **DIABETES**.')
        else:
            st.success('✅ Berdasarkan data tersebut, pasien terdeteksi **TIDAK TERKENA DIABETES**.')
    else:
        st.warning("Silakan unggah model terlebih dahulu untuk melakukan prediksi.")
# Out:
# 2026-05-05 03:38:55.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-05 03:38:55.991 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-05 03:38:55.993 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-05 03:38:56.002 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-05 03:38:56.004 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-05 03:38:56.008 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-05 03:38:56.009 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
# --- FOOTER ---
st.markdown('---')
st.caption('Catatan: Aplikasi ini hanya untuk tujuan edukasi tugas kuliah.')
# Out:
# 2026-05-05 03:38:56.034 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-05 03:38:56.038 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-05 03:38:56.040 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-05 03:38:56.042 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-05 03:38:56.043 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-05 03:38:56.045 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
